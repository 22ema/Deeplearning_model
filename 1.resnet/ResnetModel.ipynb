# %%
import torch
from torch import nn
from torch.nn.functional as F

# %%
class BasicBlock(nn.Module):
  def __init__(self, input_size):
    super().__init__()
    block_7 = nn.Conv2d(input_size, 64, (7, 7))
    max_pooling = nn.Conv2d(3, stride=2)
    block_3_64 = nn.Conv2d(64,(3, 3))
    block_3_128 = nn.Conv2d(128, (3, 3))
    block_3_256 = nn.Conv2d(256, (3, 3))
    block_3_512 = nn.Conv2d(512, (3, 3))
    fc = nn.Linear(1000)
  
  def forward(self, x):



  def resdiual_block(self, x):
